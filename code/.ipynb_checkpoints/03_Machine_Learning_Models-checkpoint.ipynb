# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_squared_error, mean_absolute_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import xgboost as xgb
from xgboost import XGBRegressor
#from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.api import VAR
from pandas.plotting import register_matplotlib_converters

from datetime import datetime

# %%
data = pd.read_csv('../data/kalshi_features_stationary.csv', index_col=0, parse_dates=True)
data.head()
# Out:
#             DayOfWeek         Open         High          Low        Close  \
# Date
# 2018-08-23          4  7420.310059  7465.870117  7405.399902  7413.839844
# 2018-08-24          5  7443.709961  7489.540039  7442.990234  7485.399902
# 2018-08-27          1  7527.370117  7560.759766  7512.020020  7559.129883
# 2018-08-28          2  7580.850098  7588.720215  7556.709961  7570.250000
# 2018-08-29          3  7585.129883  7661.950195  7583.520020  7660.180176
#
#                 Volume  OC Difference  HL Difference  OC %Change  HL %Change  \
# Date
# 2018-08-23  1888600000       6.470215      60.470215   -0.000872   -0.008100
# 2018-08-24  1892990000     -41.689941      46.549805    0.005601   -0.006215
# 2018-08-27  2333790000     -31.759766      48.739746    0.004219   -0.006446
# 2018-08-28  1980270000      10.600098      32.010254   -0.001398   -0.004218
# 2018-08-29  1909880000     -75.050293      78.430175    0.009894   -0.010236
#
#             ...  first_diff_volume  first_diff_avg_volume_10_day  \
# Date        ...
# 2018-08-23  ...                NaN                           NaN
# 2018-08-24  ...          4390000.0                    27033000.0
# 2018-08-27  ...        440800000.0                    16244000.0
# 2018-08-28  ...       -353520000.0                     1129000.0
# 2018-08-29  ...        -70390000.0                    39205000.0
#
#             first_diff_close_bracket  first_diff_short_ema  \
# Date
# 2018-08-23                       NaN                   NaN
# 2018-08-24                       0.0             21.459642
# 2018-08-27                     100.0             12.350475
# 2018-08-28                       0.0              1.190565
# 2018-08-29                     100.0             -0.614808
#
#             first_diff_long_ema  first_diff_close_lag_1  \
# Date
# 2018-08-23                  NaN                     NaN
# 2018-08-24             6.351293                     NaN
# 2018-08-27             1.134591               71.560058
# 2018-08-28            -4.673040               73.729981
# 2018-08-29            -5.936492               11.120117
#
#             first_diff_close_lag_2  first_diff_close_lag_3  \
# Date
# 2018-08-23                     NaN                     NaN
# 2018-08-24                     NaN                     NaN
# 2018-08-27                     NaN                     NaN
# 2018-08-28               71.560058                     NaN
# 2018-08-29               73.729981               71.560058
#
#             first_diff_close_lag_4  first_diff_close_lag_5
# Date
# 2018-08-23                     NaN                     NaN
# 2018-08-24                     NaN                     NaN
# 2018-08-27                     NaN                     NaN
# 2018-08-28                     NaN                     NaN
# 2018-08-29                     NaN                     NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# ## XGB Model

# %%
features = ['Open', 'High', 'Low', 'Volume', 'OC Difference',
       'HL Difference', 'OC %Change', 'HL %Change', 'Close_Status',
       'Close_Difference', 'Same Bracket', 'Avg_OC_Spread_10_Day',
       'Avg_Volume_10_Day', 'Volatility_10_Day', 'Price_Change_Magnitude',
       'Price_Direction', 'MA_Volume_Ratio', 'Close_Bracket', 'Close_Lag_5',
       'Close_Lag_4', 'Close_Lag_3', 'Close_Lag_2', 'Close_Lag_1', 'ShortEMA',
       'LongEMA', 'MACD',]

# %%
features_2 = ['Avg_OC_Spread_10_Day',
       'Avg_Volume_10_Day', 'Volatility_10_Day', 'Price_Change_Magnitude',
       'Price_Direction', 'MA_Volume_Ratio', 'Close_Lag_5',
       'Close_Lag_4', 'Close_Lag_3', 'Close_Lag_2', 'Close_Lag_1', 'ShortEMA',
       'LongEMA', 'MACD',]

# %%
X = data[features_2]
y = data['Close']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state = 42)

# %%
# Preprocessing for numerical data
ss = StandardScaler()

# Create a preprocessing and modeling pipeline
model = Pipeline(steps=[('preprocessor', ss),
                        ('model', XGBRegressor())])

param_grid = {
    'model__n_estimators': [100, 200, 300],
    'model__learning_rate': [0.01, 0.1],
    'model__max_depth': [3,5],
    'model__min_child_weight': [1,3],
    'model__subsample': [ 0.7, 1.0],
    'model__colsample_bytree': [ 0.7, 1.0]
}

# Set up the grid search
grid_search = GridSearchCV(model, param_grid, cv=3, scoring='neg_mean_squared_error', verbose=2, n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Best parameters
#print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor', StandardScaler()),
#                                        ('model',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      callbacks=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      early_stopping_rounds=None,
#                                                      enable_categorical=False,
#                                                      eval_metric=None,
#                                                      feature_types=None,
#                                                      gamma=None, gpu_id=None,
#                                                      grow_policy=None,
#                                                      importance_...
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=None, ...))]),
#              n_jobs=-1,
#              param_grid={'model__colsample_bytree': [0.7, 1.0],
#                          'model__learning_rate': [0.01, 0.1],
#                          'model__max_depth': [3, 5],
#                          'model__min_child_weight': [1, 3],
#                          'model__n_estimators': [100, 200, 300],
#                          'model__subsample': [0.7, 1.0]},
#              scoring='neg_mean_squared_error', verbose=2)

# %% [markdown]
# Best parameters: {'model__colsample_bytree': 1.0, 'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__min_child_weight': 3, 'model__n_estimators': 300, 'model__subsample': 1.0}

# %%
# Use the best model
best_model = grid_search.best_estimator_

# Predictions
y_pred = best_model.predict(X_test)

# Evaluation metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 16759.542113231175
# R^2 Score: 0.9977927481083289

# %%
print("Best parameters:", grid_search.best_params_)
# Out:
# Best parameters: {'model__colsample_bytree': 1.0, 'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__min_child_weight': 3, 'model__n_estimators': 300, 'model__subsample': 1.0}

# %%
plt.figure(figsize=(12, 6))
plt.scatter(y_test.index, y_test, label='Actual Close Price', alpha=0.6)
plt.scatter(y_test.index, y_pred, label='Predicted Close Price', alpha=0.6)
plt.title('XGBoost Model Predictions vs Actual')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# ##### Lets do some analysis on the model

# %%
min_price = y.min()
max_price = y.max()
range_price = max_price - min_price
std_dev = y.std()

print(f"Minimum 'Close' Price: {min_price}")
print(f"Maximum 'Close' Price: {max_price}")
print(f"Range of 'Close' Prices: {range_price}")
print(f"Standard Deviation of 'Close' Prices: {std_dev}")
print(f"Mean Squared Error: {mse}")
# Out:
# Minimum 'Close' Price: 5899.350098
# Maximum 'Close' Price: 16573.339844
# Range of 'Close' Prices: 10673.989746
# Standard Deviation of 'Close' Prices: 2835.4356489334064
# Mean Squared Error: 3640.028851634541

# %%
# Ensure you have a model fitted with the best parameters from GridSearchCV or a single run
feature_importances = best_model.named_steps['model'].feature_importances_

# Create a pandas Series for easy plotting
import pandas as pd
importances = pd.Series(feature_importances, index=X.columns)

# Sort importances
sorted_importances = importances.sort_values()

# Plot
plt.figure(figsize=(14, 7))
sorted_importances.plot(kind='barh')
plt.title('Feature Importance')
plt.show()
# Out:
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   1.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   2.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   2.0s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.1s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   1.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   2.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   2.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.1s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.1s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.1s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   2.0s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   1.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   2.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# ...
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.8s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   1.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   1.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   1.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   1.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   2.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=300, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=0.7; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=3, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   0.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=0.7; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100, model__subsample=1.0; total time=   0.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200, model__subsample=1.0; total time=   0.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=0.7; total time=   0.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100, model__subsample=1.0; total time=   0.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200, model__subsample=1.0; total time=   1.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.1, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300, model__subsample=1.0; total time=   1.1s

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Actual vs. Predicted Close Price Over Time
plt.figure(figsize=(15, 7))
plt.scatter(y_test.index, y_test, label='Actual Close Price', color='blue', linewidth=1)
plt.scatter(y_test.index, y_pred, label='Predicted Close Price', color='red', linestyle='--', linewidth=1)
plt.title('Model Performance Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format the dates as 'Year-Month'
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))  # Set major ticks interval to every 3 months
plt.gcf().autofmt_xdate()  # Auto-format the dates to avoid overlap
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
import seaborn as sns

# Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error (MAE): {mae}")

# Residuals
residuals = y_test - y_pred

# Distribution Plot of Residuals
plt.figure(figsize=(15, 7))
sns.histplot(residuals, kde=True, color='purple')
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.show()
# Out:
# Mean Absolute Error (MAE): 95.89048580046541

# %% [markdown]
# Next steps:
# - Evaluate the distirbution plot above
# - Start making predictions for next day
# - Make predicitons input where I provide the open price and it can give me the answer based off historical data it has already, we need to start forecasting
